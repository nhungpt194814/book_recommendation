# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from fuzzywuzzy import process
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('/kaggle/input/bookkeywords/keywords.csv')

# %%
# Transform author names, publisher into single token
data["author2"] = data["author"].str.strip().str.replace(' ','_')
data["publisher2"] = data["publisher"].str.strip().str.replace(' ','_')
# Out:
#                                                  url                    title  \
# 0  https://www.goodreads.com/book/show/2165.The_O...  the old man and the sea
# 1  https://www.goodreads.com/book/show/10507293-t...            the selection
# 2  https://www.goodreads.com/book/show/5148.A_Sep...         a separate peace
#
#                                          description  \
# 0  librarian note alternate cover edition found h...
# 1  thirty five girls selection chance lifetime op...
# 2  american classic great bestseller thirty years...
#
#                                             imageUrl  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
#
#                                               genres   publisher  \
# 0  american classic literature novels 20th centur...    scribner
# 1  fantasy teen fiction science fiction young adu...  harperteen
# 2  historical fiction novels fiction high school ...    scribner
#
#              author                               characters language  \
# 0  ernest hemingway                         manolin santiago  English
# 1        kiera cass  america singer prince maxon aspen leger  English
# 2      john knowles                   gene forrester phineas  English
#
#           series                           lemmatized_description_x  \
# 0            NaN  librarian note alternate cover edition found h...
# 1  the selection  thirty five girl selection chance lifetime opp...
# 2            NaN  american classic great bestseller thirty year ...
#
#                                                sum_x  \
# 0  the old man and the sea ernest_hemingway scrib...
# 1  the selection kiera_cass harperteen thirty fiv...
# 2  a separate peace john_knowles scribner america...
#
#                             lemmatized_description_y  \
# 0  librarian note alternate cover edition found h...
# 1  thirty five girl selection chance lifetime opp...
# 2  american classic great bestseller thirty year ...
#
#                                                sum_y  \
# 0  the old man and the sea ernest_hemingway scrib...
# 1  the selection kiera_cass harperteen thirty fiv...
# 2  a separate peace john_knowles scribner america...
#
#                                          keywords           author2  \
# 0            marlin novel nobel literature author  ernest_hemingway
# 1          prince dreamed lifetime life nightmare        kiera_cass
# 2  adolescence bestseller knowles peace innocence      john_knowles
#
#    publisher2
# 0    scribner
# 1  harperteen
# 2    scribner

# %%
# Merge all textual information to create summary
data["sum"] = data[["title", 'author2', 'publisher2', 'keywords','language','series','characters','genres']].fillna('').agg(' '.join, axis=1)
data = data.drop(columns=['author2', 'publisher2'])

data = data.drop(columns=['sum_x','sum_y','lemmatized_description_y','lemmatized_description_x','keywords','description','genres','publisher','author','characters','language','series'])
data.head(3)
# Out:
#                                                  url                    title  \
# 0  https://www.goodreads.com/book/show/2165.The_O...  the old man and the sea
# 1  https://www.goodreads.com/book/show/10507293-t...            the selection
# 2  https://www.goodreads.com/book/show/5148.A_Sep...         a separate peace
#
#                                             imageUrl  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
#
#                                                  sum
# 0  the old man and the sea ernest_hemingway scrib...
# 1  the selection kiera_cass harperteen prince dre...
# 2  a separate peace john_knowles scribner adolesc...

# %%
model_data = data.copy()
model_data['index'] = range(1, len(model_data) + 1)
model_data.head(2)
# Out:
#                                                  url                    title  \
# 0  https://www.goodreads.com/book/show/2165.The_O...  the old man and the sea
# 1  https://www.goodreads.com/book/show/10507293-t...            the selection
#
#                                             imageUrl  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
#
#                                                  sum  index
# 0  the old man and the sea ernest_hemingway scrib...      1
# 1  the selection kiera_cass harperteen prince dre...      2

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer = 'word',
                min_df=3,
                max_df = 0.6,
                stop_words="english",
                encoding = 'utf-8')
tfidf_matrix = tfidf_vectorizer.fit_transform(model_data['sum'])

# %%
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
def find_closest_match(user_input, available_options):
    
    closest_match, score = process.extractOne(user_input, available_options)

    threshold = 80  
    if score >= threshold:
        return closest_match
    else:
        return user_input

# %%
def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

# %%
def content_based_recommender(book_titles):
    valid_titles = []
    invalid_titles = []
    sum_valid_titles = []

    for title in book_titles:
        str_title = str(title).lower()
        str_title = find_closest_match(str_title, model_data['title'].values)
        if str_title in model_data['title'].values:
            valid_titles.append(str_title)
            book_item = model_data[model_data['title']==str_title]
            book_values = book_item['sum'].values
            book_values_str = ', '.join(map(str, book_values))
            sum_valid_titles.append(book_values_str)
        else:
            invalid_titles.append(str_title)

    if not valid_titles:
        print('No valid titles found in the dataset. Please check spelling.')
        return
    query_vecs = tfidf_vectorizer.transform(sum_valid_titles)
    avg_query_vec = np.mean(query_vecs, axis=0)
    avg_query_vec = np.asarray(avg_query_vec)
    
    similarities = cosine_similarity(avg_query_vec, tfidf_matrix)

    indices = np.argpartition(similarities[0], -6)[-6:]
    results = data.iloc[indices]
    results = results.drop(columns=['sum'])
    
#     print(results)
    print("\nRecommendations books:")
    display(results.head(5).style.format({'url': make_clickable, 'imageUrl': show_image}))

    if invalid_titles:
        print(f"\nTitles not found in the dataset: {', '.join(invalid_titles)}")

# %%
content_based_recommender(["Harry Potter and the Philosopher's Stone 1"])
# Out:
# Recommendations books:
# <style type="text/css">
# </style>
# <table id="T_6c884">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c884_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_6c884_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_6c884_level0_col2" class="col_heading level0 col2" >imageUrl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c884_level0_row0" class="row_heading level0 row0" >1446</th>
#       <td id="T_6c884_row0_col0" class="data row0 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/5.Harry_Potter_and_the_Prisoner_of_Azkaban">Goodreads</a></td>
#       <td id="T_6c884_row0_col1" class="data row0 col1" >harry potter and the prisoner of azkaban</td>
#       <td id="T_6c884_row0_col2" class="data row0 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1630547330i/5.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1630547330i/5.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_6c884_level0_row1" class="row_heading level0 row1" >8315</th>
#       <td id="T_6c884_row1_col0" class="data row1 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/42844155-harry-potter-and-the-sorcerer-s-stone">Goodreads</a></td>
#       <td id="T_6c884_row1_col1" class="data row1 col1" >harry potter and the sorcerer’s stone</td>
#       <td id="T_6c884_row1_col2" class="data row1 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1598823299i/42844155.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1598823299i/42844155.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_6c884_level0_row2" class="row_heading level0 row2" >1598</th>
#       <td id="T_6c884_row2_col0" class="data row2 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/15881.Harry_Potter_and_the_Chamber_of_Secrets">Goodreads</a></td>
#       <td id="T_6c884_row2_col1" class="data row2 col1" >harry potter and the chamber of secrets</td>
#       <td id="T_6c884_row2_col2" class="data row2 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1474169725i/15881.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1474169725i/15881.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_6c884_level0_row3" class="row_heading level0 row3" >6857</th>
#       <td id="T_6c884_row3_col0" class="data row3 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/72193.Harry_Potter_and_the_Philosopher_s_Stone">Goodreads</a></td>
#       <td id="T_6c884_row3_col1" class="data row3 col1" >harry potter and the philosopher’s stone</td>
#       <td id="T_6c884_row3_col2" class="data row3 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1170803558l/72193.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1170803558l/72193.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_6c884_level0_row4" class="row_heading level0 row4" >1463</th>
#       <td id="T_6c884_row4_col0" class="data row4 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/136251.Harry_Potter_and_the_Deathly_Hallows">Goodreads</a></td>
#       <td id="T_6c884_row4_col1" class="data row4 col1" >harry potter and the deathly hallows</td>
#       <td id="T_6c884_row4_col2" class="data row4 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1663805647i/136251.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1663805647i/136251.jpg" width=50></img></a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # User

# %%
ratings = pd.read_json('/kaggle/input/user-comment/clean_rate_data.jl',lines=True)

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443077 entries, 0 to 443076
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   book_url     443077 non-null  object
#  1   title        443077 non-null  object
#  2   user         443077 non-null  object
#  3   user_rate    443077 non-null  int64
#  4   user_review  443077 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 16.9+ MB

# %%
# create ratings df
ratings = ratings.drop(columns = ['title','user_review'])
ratings.head()
# Out:
#                                             book_url  \
# 0  https://www.goodreads.com/book/show/205650.Fle...
# 1  https://www.goodreads.com/book/show/205650.Fle...
# 2  https://www.goodreads.com/book/show/205650.Fle...
# 3  https://www.goodreads.com/book/show/205650.Fle...
# 4  https://www.goodreads.com/book/show/205650.Fle...
#
#                           user  user_rate
# 0  7407364-luffy-oda-s-version          2
# 1              8655084-phrynne          5
# 2                3569723-ammar          4
# 3                18202588-anna          5
# 4                     13056902          4

# %%
# create users df
users = ratings['user']
users = users.drop_duplicates()
users.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 152536 entries, 0 to 443076
# Series name: user
# Non-Null Count   Dtype
# --------------   -----
# 152536 non-null  object
# dtypes: object(1)
# memory usage: 2.3+ MB

# %%
ratings_merge = pd.merge(ratings, model_data, left_on = 'book_url', right_on='url', how = 'inner')
ratings_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416997 entries, 0 to 416996
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   book_url   416997 non-null  object
#  1   user       416997 non-null  object
#  2   user_rate  416997 non-null  int64
#  3   url        416997 non-null  object
#  4   title      416997 non-null  object
#  5   imageUrl   416548 non-null  object
#  6   sum        416997 non-null  object
#  7   index      416997 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 25.5+ MB

# %%
ratings_merge = ratings_merge.drop(columns = ['book_url'])
ratings_merge = ratings_merge.drop_duplicates()

# %%
# all_books = pd.read_json('/kaggle/input/book-detail/clean_book_data.jl',lines=True)
# def popularity_based():
#     sorted_books = all_books.sort_values(by=['avgRating', 'ratingsCount'], ascending=[False, False])
#     top_10_books = sorted_books.head(10)
#     return top_10_books[['url','title','description']]

# %%
popularity_based()
# Out:
#                                                      url  \
# 17225  https://www.goodreads.com/book/show/13554552-s...
# 17044  https://www.goodreads.com/book/show/45062775-b...
# 19166  https://www.goodreads.com/book/show/43798164-i...
# 27376  https://www.goodreads.com/book/show/196939567-...
# 12315  https://www.goodreads.com/book/show/13036945-m...
# 28635  https://www.goodreads.com/book/show/30229303-g...
# 19146  https://www.goodreads.com/book/show/59772668-s...
# 22112  https://www.goodreads.com/book/show/36427079-n...
# 19631  https://www.goodreads.com/book/show/27424051-f...
# 4802   https://www.goodreads.com/book/show/37757785-a...
#
#                                                    title  \
# 17225                                     Sapphire Reign
# 17044  Broken Promises: The Suspenseful Sequel To The...
# 19166              I'm a F***ing Star: Get on Reality TV
# 27376                                      Original Twin
# 12315   MAJI The untold adventure of the men of the East
# 28635  Going It Alone: Why Just Writing Your Book Is ...
# 19146                          Surviving The Second Tier
# 22112                                Never Marry a Biker
# 19631  F.I.G.H.T.: Family Inspires Great Hope Togethe...
# 4802                                    Armée des ombres
#
#                                              description
# 17225  opens 10 years after the events in kings amp q...
# 17044  for beauty all she wants is for her life to go...
# 19166  this short but impressively in depth book will...
# 27376  a twisty crossover thriller that will have rea...
# 12315  young zebedeo is between boyhood and manhood w...
# 28635  going it alone why just writing your book is n...
# 19146  sicily sis jones is the only undefeated colleg...
# 22112  this book is the follow up to pack your bags a...
# 19631  when it is your child the urge to fight is rel...
# 4802                                    arm e des ombres

# %%
def book_recommend_with_user(user_id):
#     get list of books that user rated
    user_ratings = ratings_merge[ratings_merge['user']==user_id]
    user_book_index = user_ratings['index'].values
    user_book_rates = user_ratings['user_rate']
#     get tfidf vector
    tfidf_user_book = tfidf_matrix[user_book_index, : ]
    
#     build model to predict rate of unread book
    X = tfidf_user_book.toarray()
    y = user_book_rates
    model = LinearRegression()
    model.fit(X, y)
    
    tfidf_rate = pd.DataFrame(tfidf_matrix.toarray(), columns=[f'tfidf_{i}' for i in range(tfidf_matrix.shape[1])])
    tfidf_rate['predict_rate'] = model.predict(tfidf_matrix)
    
#     unread_books = tfidf_rate[~tfidf_rate.index.isin(user_ratings['index'])]
    top_results = tfidf_rate.nlargest(10, 'predict_rate')
    results = data.iloc[top_results.index]
    results = results.drop(columns = ['sum'])
    print("\nRecommendations books:")
    display(results.head(5).style.format({'url': make_clickable, 'imageUrl': show_image}))

# %%
user_id_input = '1305690'
user_id = find_closest_match(user_id_input, users.values)
book_recommend_with_user(user_id)
# Out:
# Index([1825, 28234, 3771, 30788, 1692, 9724, 19646, 10894, 2789, 17313], dtype='int64')
#
# Recommendations books:
# <style type="text/css">
# </style>
# <table id="T_d421d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d421d_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_d421d_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_d421d_level0_col2" class="col_heading level0 col2" >imageUrl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d421d_level0_row0" class="row_heading level0 row0" >1825</th>
#       <td id="T_d421d_row0_col0" class="data row0 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/49599733-a-gracious-enemy">Goodreads</a></td>
#       <td id="T_d421d_row0_col1" class="data row0 col1" >a gracious enemy</td>
#       <td id="T_d421d_row0_col2" class="data row0 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1605403217i/49599733.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1605403217i/49599733.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_d421d_level0_row1" class="row_heading level0 row1" >28234</th>
#       <td id="T_d421d_row1_col0" class="data row1 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/930193.The_Crooked_Hinge">Goodreads</a></td>
#       <td id="T_d421d_row1_col1" class="data row1 col1" >the crooked hinge</td>
#       <td id="T_d421d_row1_col2" class="data row1 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1290832481i/930193.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1290832481i/930193.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_d421d_level0_row2" class="row_heading level0 row2" >3771</th>
#       <td id="T_d421d_row2_col0" class="data row2 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/60657747-a-gracious-enemy-after-the-war-volume-one">Goodreads</a></td>
#       <td id="T_d421d_row2_col1" class="data row2 col1" >a gracious enemy & after the war volume one</td>
#       <td id="T_d421d_row2_col2" class="data row2 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1647831441i/60657747.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1647831441i/60657747.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_d421d_level0_row3" class="row_heading level0 row3" >30788</th>
#       <td id="T_d421d_row3_col0" class="data row3 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/930199.Hag_s_Nook">Goodreads</a></td>
#       <td id="T_d421d_row3_col1" class="data row3 col1" >hag's nook</td>
#       <td id="T_d421d_row3_col2" class="data row3 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1260625238i/930199.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1260625238i/930199.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_d421d_level0_row4" class="row_heading level0 row4" >1692</th>
#       <td id="T_d421d_row4_col0" class="data row4 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/613283.Princess">Goodreads</a></td>
#       <td id="T_d421d_row4_col1" class="data row4 col1" >princess: a true story of life behind the veil in saudi arabia</td>
#       <td id="T_d421d_row4_col2" class="data row4 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1377538002i/613283.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1377538002i/613283.jpg" width=50></img></a></td>
#     </tr>
#   </tbody>
# </table>
