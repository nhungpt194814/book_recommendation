# %%
import pandas as pd
data = pd.read_csv('/kaggle/input/bookkeywords/keywords.csv')

# %%
data.head(3)
# Out:
#                                                  url                    title  \
# 0  https://www.goodreads.com/book/show/2165.The_O...  the old man and the sea
# 1  https://www.goodreads.com/book/show/10507293-t...            the selection
# 2  https://www.goodreads.com/book/show/5148.A_Sep...         a separate peace
#
#                                          description  \
# 0  librarian note alternate cover edition found h...
# 1  thirty five girls selection chance lifetime op...
# 2  american classic great bestseller thirty years...
#
#                                             imageUrl  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
#
#                                               genres   publisher  \
# 0  american classic literature novels 20th centur...    scribner
# 1  fantasy teen fiction science fiction young adu...  harperteen
# 2  historical fiction novels fiction high school ...    scribner
#
#              author                               characters language  \
# 0  ernest hemingway                         manolin santiago  English
# 1        kiera cass  america singer prince maxon aspen leger  English
# 2      john knowles                   gene forrester phineas  English
#
#           series                           lemmatized_description_x  \
# 0            NaN  librarian note alternate cover edition found h...
# 1  the selection  thirty five girl selection chance lifetime opp...
# 2            NaN  american classic great bestseller thirty year ...
#
#                                                sum_x  \
# 0  the old man and the sea ernest_hemingway scrib...
# 1  the selection kiera_cass harperteen thirty fiv...
# 2  a separate peace john_knowles scribner america...
#
#                             lemmatized_description_y  \
# 0  librarian note alternate cover edition found h...
# 1  thirty five girl selection chance lifetime opp...
# 2  american classic great bestseller thirty year ...
#
#                                                sum_y  \
# 0  the old man and the sea ernest_hemingway scrib...
# 1  the selection kiera_cass harperteen thirty fiv...
# 2  a separate peace john_knowles scribner america...
#
#                                          keywords
# 0            marlin novel nobel literature author
# 1          prince dreamed lifetime life nightmare
# 2  adolescence bestseller knowles peace innocence

# %%
data.tail(3)
# Out:
#                                                      url  \
# 31561  https://www.goodreads.com/book/show/53136.Bloo...
# 31562  https://www.goodreads.com/book/show/36544896-b...
# 31563  https://www.goodreads.com/book/show/9260507-5-...
#
#                                                    title  \
# 31561                                         bloodangel
# 31562                                  before she sleeps
# 31563  5 very good reasons to punch a dolphin in the ...
#
#                                              description  \
# 31561  downtown manhattan rising young painter haunte...
# 31562  modern beautiful green city capital south west...
# 31563  prepare laugh ass hilarity theoatmeal com pres...
#
#                                                 imageUrl  \
# 31561  https://images-na.ssl-images-amazon.com/images...
# 31562  https://images-na.ssl-images-amazon.com/images...
# 31563  https://images-na.ssl-images-amazon.com/images...
#
#                                                   genres    publisher  \
# 31561  supernatural magic dark horror fiction dark fa...          roc
# 31562  pakistan speculative fiction science fiction f...   delphinium
# 31563  graphic novels comics webcomic comic book humo...  fisicalbook
#
#                           author characters language       series  \
# 31561               justine musk        NaN  English   bloodangel
# 31562                  bina shah        NaN  English          NaN
# 31563  matthew inman the oatmeal        NaN  English  the oatmeal
#
#                                 lemmatized_description_x  \
# 31561  downtown manhattan rising young painter haunte...
# 31562  modern beautiful green city capital south west...
# 31563  prepare laugh as hilarity theoatmeal com prese...
#
#                                                    sum_x  \
# 31561  bloodangel justine_musk roc downtown manhattan...
# 31562  before she sleeps bina_shah delphinium modern ...
# 31563  5 very good reasons to punch a dolphin in the ...
#
#                                 lemmatized_description_y  \
# 31561  downtown manhattan rising young painter haunte...
# 31562  modern beautiful green city capital south west...
# 31563  prepare laugh as hilarity theoatmeal com prese...
#
#                                                    sum_y  \
# 31561  bloodangel justine_musk roc downtown manhattan...
# 31562  before she sleeps bina_shah delphinium modern ...
# 31563  5 very good reasons to punch a dolphin in the ...
#
#                                                 keywords
# 31561            painter singer manhattan haunted orphan
# 31562  handmaid patriarchal dystopian authoritarianis...
# 31563                    cat hamster potty kitten quirky

# %%
# Transform author names, publisher into single token
data["author2"] = data["author"].str.strip().str.replace(' ','_')
data["publisher2"] = data["publisher"].str.strip().str.replace(' ','_')
data.head(3)
# Out:
#                                                  url                    title  \
# 0  https://www.goodreads.com/book/show/2165.The_O...  the old man and the sea
# 1  https://www.goodreads.com/book/show/10507293-t...            the selection
# 2  https://www.goodreads.com/book/show/5148.A_Sep...         a separate peace
#
#                                          description  \
# 0  librarian note alternate cover edition found h...
# 1  thirty five girls selection chance lifetime op...
# 2  american classic great bestseller thirty years...
#
#                                             imageUrl  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
#
#                                               genres   publisher  \
# 0  american classic literature novels 20th centur...    scribner
# 1  fantasy teen fiction science fiction young adu...  harperteen
# 2  historical fiction novels fiction high school ...    scribner
#
#              author                               characters language  \
# 0  ernest hemingway                         manolin santiago  English
# 1        kiera cass  america singer prince maxon aspen leger  English
# 2      john knowles                   gene forrester phineas  English
#
#           series                           lemmatized_description_x  \
# 0            NaN  librarian note alternate cover edition found h...
# 1  the selection  thirty five girl selection chance lifetime opp...
# 2            NaN  american classic great bestseller thirty year ...
#
#                                                sum_x  \
# 0  the old man and the sea ernest_hemingway scrib...
# 1  the selection kiera_cass harperteen thirty fiv...
# 2  a separate peace john_knowles scribner america...
#
#                             lemmatized_description_y  \
# 0  librarian note alternate cover edition found h...
# 1  thirty five girl selection chance lifetime opp...
# 2  american classic great bestseller thirty year ...
#
#                                                sum_y  \
# 0  the old man and the sea ernest_hemingway scrib...
# 1  the selection kiera_cass harperteen thirty fiv...
# 2  a separate peace john_knowles scribner america...
#
#                                          keywords           author2  \
# 0            marlin novel nobel literature author  ernest_hemingway
# 1          prince dreamed lifetime life nightmare        kiera_cass
# 2  adolescence bestseller knowles peace innocence      john_knowles
#
#    publisher2
# 0    scribner
# 1  harperteen
# 2    scribner

# %%
# Merge all textual information to create summary
data["sum"] = data[["title", 'author2', 'publisher2', 'keywords','language','series','characters','genres']].fillna('').agg(' '.join, axis=1)
data = data.drop(columns=['author2', 'publisher2'])

data = data.drop(columns=['sum_x','sum_y','lemmatized_description_y','lemmatized_description_x','keywords','description','genres','publisher','author','characters','language','series'])
data.head(3)
# Out:
#                                                  url                    title  \
# 0  https://www.goodreads.com/book/show/2165.The_O...  the old man and the sea
# 1  https://www.goodreads.com/book/show/10507293-t...            the selection
# 2  https://www.goodreads.com/book/show/5148.A_Sep...         a separate peace
#
#                                             imageUrl  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
#
#                                                  sum
# 0  the old man and the sea ernest_hemingway scrib...
# 1  the selection kiera_cass harperteen prince dre...
# 2  a separate peace john_knowles scribner adolesc...

# %%
model_data = data.copy()
model_data['index'] = range(1, len(model_data) + 1)
model_data.head(2)
# Out:
#                                                  url                    title  \
# 0  https://www.goodreads.com/book/show/2165.The_O...  the old man and the sea
# 1  https://www.goodreads.com/book/show/10507293-t...            the selection
#
#                                             imageUrl  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
#
#                                                  sum  index
# 0  the old man and the sea ernest_hemingway scrib...      1
# 1  the selection kiera_cass harperteen prince dre...      2

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(analyzer = 'word',
                min_df=3,
                max_df = 0.6,
                stop_words="english",
                encoding = 'utf-8')
tfidf_matrix = tfidf_vectorizer.fit_transform(model_data['sum'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
import numpy as np
def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

# %%
def content_based_recommender(book_titles):
    valid_titles = []
    invalid_titles = []

    for title in book_titles:
        str_title = str(title)

        if str_title in model_data['title'].values:
            valid_titles.append(str_title)
        else:
            invalid_titles.append(str_title)

    if not valid_titles:
        print('No valid titles found in the dataset. Please check spelling.')
        return

    query_vecs = tfidf_vectorizer.transform(valid_titles)
    avg_query_vec = np.mean(query_vecs, axis=0)
    avg_query_vec = np.asarray(avg_query_vec)
    
    similarities = cosine_similarity(avg_query_vec, tfidf_matrix)

    indices = np.argpartition(similarities[0], -6)[-6:]
    results = data.iloc[indices]
    results = results.drop(columns=['sum'])
    
#     print(results)
    print("\nRecommendations books:")
    display(results.head(5).style.format({'url': make_clickable, 'imageUrl': show_image}))

    if invalid_titles:
        print(f"\nTitles not found in the dataset: {', '.join(invalid_titles)}")

content_based_recommender(["ghost story", "the feynman lectures on physics", "data science for beginners"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_46f76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46f76_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_46f76_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_46f76_level0_col2" class="col_heading level0 col2" >imageUrl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46f76_level0_row0" class="row_heading level0 row0" >29468</th>
#       <td id="T_46f76_row0_col0" class="data row0 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/44415062-two-mothers">Goodreads</a></td>
#       <td id="T_46f76_row0_col1" class="data row0 col1" >two mothers: a ghost story novella</td>
#       <td id="T_46f76_row0_col2" class="data row0 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1552394261i/44415062.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1552394261i/44415062.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_46f76_level0_row1" class="row_heading level0 row1" >5893</th>
#       <td id="T_46f76_row1_col0" class="data row1 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/439092.The_Old_Willis_Place">Goodreads</a></td>
#       <td id="T_46f76_row1_col1" class="data row1 col1" >the old willis place</td>
#       <td id="T_46f76_row1_col2" class="data row1 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1436754239i/439092.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1436754239i/439092.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_46f76_level0_row2" class="row_heading level0 row2" >9731</th>
#       <td id="T_46f76_row2_col0" class="data row2 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/37542187-ghost">Goodreads</a></td>
#       <td id="T_46f76_row2_col1" class="data row2 col1" >ghost</td>
#       <td id="T_46f76_row2_col2" class="data row2 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1513347544i/37542187.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1513347544i/37542187.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_46f76_level0_row3" class="row_heading level0 row3" >95</th>
#       <td id="T_46f76_row3_col0" class="data row3 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/19581.Ghost_Story">Goodreads</a></td>
#       <td id="T_46f76_row3_col1" class="data row3 col1" >ghost story</td>
#       <td id="T_46f76_row3_col2" class="data row3 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1441771752i/19581.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1441771752i/19581.jpg" width=50></img></a></td>
#     </tr>
#     <tr>
#       <th id="T_46f76_level0_row4" class="row_heading level0 row4" >10890</th>
#       <td id="T_46f76_row4_col0" class="data row4 col0" ><a target="_blank" href="https://www.goodreads.com/book/show/27313056-ghost-girls">Goodreads</a></td>
#       <td id="T_46f76_row4_col1" class="data row4 col1" >ghost girls</td>
#       <td id="T_46f76_row4_col2" class="data row4 col2" ><a href="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1445995953i/27313056.jpg"><img src="https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1445995953i/27313056.jpg" width=50></img></a></td>
#     </tr>
#   </tbody>
# </table>
